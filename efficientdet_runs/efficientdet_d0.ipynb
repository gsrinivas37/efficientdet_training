# %%
# !wget https://github.com/protocolbuffers/protobuf/releases/download/v22.3/protoc-22.3-linux-x86_64.zip
# !unzip /root/protoc-22.3-linux-x86_64.zip

# !git clone https://github.com/tensorflow/models.git
# %cd models/research/

# %%
# From within TensorFlow/models/research/
# !/root/bin/protoc object_detection/protos/*.proto --python_out=.

# !pip install cython

# From within TensorFlow/models/research/
# !cp object_detection/packages/tf2/setup.py .
# !python -m pip install .

# From within TensorFlow/models/research/
# !python object_detection/builders/model_builder_tf2_test.py

# %%
# !apt install libgl1-mesa-glx -y
# !pip install gdown
# !pip install supervision
# !pip install torchvision

import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# %%
# %cd /root
# !rm -rf generate_tf_records
# !git clone https://github.com/gsrinivas37/generate_tf_records.git
import gdown
FILE_ID = '1HPIiiM7Wygb3vK_AsOArmtlATI34Qgc8'
URL = f"https://drive.google.com/uc?id={FILE_ID}"
gdown.download(URL, "images.zip", quiet=False)
# !unzip images.zip
# !rm images.zip

# %%
# !rm -rf data/
# !python /root/generate_tf_records/main.py "/root/Pollinators-17_COCO_fullsize_aug_null_nf" 512

# %%
# %cd /root/models/research
# !wget http://download.tensorflow.org/models/object_detection/tf2/20200711/efficientdet_d0_coco17_tpu-32.tar.gz
# !tar -xf efficientdet_d0_coco17_tpu-32.tar.gz

# %%
# !mv /root/data .

# %%
# !rm -rf my_model
# !python object_detection/model_main_tf2.py --pipeline_config_path=efficientdet_d0.config --model_dir=my_model --alsologtostderr
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0425 11:12:45.763108 140209392850752 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: None
# I0425 11:12:45.768532 140209392850752 config_util.py:552] Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# ...

# %%
# Running evaluation metrics
# !python object_detection/model_main_tf2.py --pipeline_config_path=efficientdet_d0.config --model_dir=my_model --checkpoint_dir=my_model
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0425 13:43:34.810164 140684931569472 model_lib_v2.py:1089] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I0425 13:43:34.810359 140684931569472 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# ...

# %%
# !python object_detection/exporter_main_v2.py --input_type image_tensor --pipeline_config_path=efficientdet_d0.config --trained_checkpoint_dir=my_model --output_directory exported_model_d0
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# I0425 13:45:41.521917 140192276141888 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b0
# I0425 13:45:41.522090 140192276141888 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 64
# I0425 13:45:41.522172 140192276141888 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 3
# ...
